# %%
import random
import csv
import os
import math
import matplotlib.pyplot as plt
from tqdm import tqdm
from google.colab import files

# %%
SHAPE_TYPES = ["rectangle", "triangle", "circle"]
OUTPUT_DIR = "/content/shapes3/"

# %%
if not os.path.exists(OUTPUT_DIR):
    os.mkdir(OUTPUT_DIR)

# %%
def label_shape(parts, black_parts):
    """
    Label the shape according to the fraction of black parts.
    Returns a label in the range [0.0, 1.0] representing the fraction of black parts in the shape.
    """
    n_black = sum([1 for i in range(len(parts)) if parts[i] == 1 and black_parts[i] == 1])
    n_total = sum(parts)
    if n_total == 0:
        return 0.0
    return n_black / n_total

# %%
def generate_shape():
    """
    Generate a random shape (rectangle, triangular or circle), divided into parts, some of which are black and some are white.
    Returns a tuple (shape_type, parts, black_parts) where shape_type is a string representing the shape type,
    parts is a list of 0's and 1's representing the parts of the shape, and black_parts is a list of the same length
    indicating which parts are black (1) and which are white (0).
    """
    shape_type = random.choice(SHAPE_TYPES)  # Choose a random shape type
    if shape_type == "rectangle":
        n_parts = random.randint(2, 6)  # Choose a random number of parts for the shape
        parts = [random.randint(0, 1) for _ in range(n_parts)]  # Generate a random pattern of parts
        black_parts = [random.randint(0, 1) for _ in range(n_parts)]  # Assign black/white to each part randomly
    elif shape_type == "triangle":
        n_parts = 3  # Triangles have 3 parts
        parts = [1, 1, 1]  # Triangles are always divided into 3 equal parts
        black_parts = [random.randint(0, 1) for _ in range(n_parts)]  # Assign black/white to each part randomly
    elif shape_type == "circle":
        n_parts = random.randint(3, 7)  # Choose a random number of parts for the shape
        parts = [1 for _ in range(n_parts)]  # Circles are always divided into equal parts
        black_parts = [random.randint(0, 1) for _ in range(n_parts)]  # Assign black/white to each part randomly
    return shape_type, parts, black_parts

# %%
def generate_pie(filename):
  a = 0
  b = 0

  while a+b == 0:
    a = random.randint(0,5)
    b = random.randint(0,5)

  fraction = f"{a}/{a+b}"

  fractions = []
  for i in range(a+b):
    fractions.append(1)

  colors = []
  for i in range(a):
    gray_shade = random.uniform(0.2, 0.8)
    colors.append((gray_shade, gray_shade, gray_shade))

  for i in range(b):
    colors.append('white')

  fig, ax = plt.subplots()
  wedges, _ = ax.pie(fractions, colors=colors, wedgeprops={'linewidth': 2, 'edgecolor': 'black'})
  ax.axis('equal')

  for wedge in wedges:
      wedge.set_linestyle('-')
      wedge.set_linewidth(2)
      wedge.set_edgecolor('black')

  plt.savefig(filename, bbox_inches='tight', pad_inches=0.5)
  plt.close()

  return a / (a + b), f"{a}/{a+b}"

# %%
def generate_rectangle(filename):
  def generate_random_list(length):
    """Generates a list of random 1s and 0s of the given length."""
    return [random.randint(0, 1) for _ in range(length)]

  def create_grid(lst):
      """
      Takes a list of 0s and 1s and creates a grid with a random number of rows and columns,
      where each cell is colored white (0) or gray (1).
      """
      n = len(lst)
      configurations = [
          (n, 1),
          (1, n),
          (2, n//2),
          (n//2, 2),
          (3, n//3),
          (n//3, 3),
      ]

      flag = False
      while not flag:
        rows, cols = random.choice(configurations)
        if rows * cols == n:
          flag = True
      if not flag:
        raise ValueError("Input list length is not compatible with a rectangular grid.")
      grid = [[0 for _ in range(cols)] for _ in range(rows)]

      for i in range(rows):
          for j in range(cols):
              if lst[i*cols + j] == 1:
                  gray_shade = random.uniform(0.2, 0.8)
                  grid[i][j] = (gray_shade, gray_shade, gray_shade)  # Gray cell
              else:
                  grid[i][j] = (1, 1, 1)  # White cell

      return grid

  lst = generate_random_list(random.randint(1,9))
  grid = create_grid(lst)

  fig, ax = plt.subplots()
  ax.imshow(grid)

  ax.grid(which='minor', color='black', linestyle='-', linewidth=2)
  ax.set_xticklabels([])
  ax.set_yticklabels([])
  ax.set_axis_off()

  for i in range(len(grid)):
      for j in range(len(grid[i])):
          rect = plt.Rectangle((j-0.5, i-0.5), 1, 1, fill=False, edgecolor='black', linewidth=2)
          ax.add_patch(rect)

  plt.savefig(filename, bbox_inches='tight', pad_inches=0.5)
  plt.close()

  return lst.count(1) / len(lst), f"{lst.count(1)}/{len(lst)}"

# %%
def generate_triangles(filename):
    num_triangles = random.randint(1, 6)
    white_gray_triangles = [random.randint(0, 1) for _ in range(num_triangles)]

    # Create a figure and axes
    fig, ax = plt.subplots()
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.set_axis_off()

    # Define the coordinates of the first triangle
    x1 = [0, 1, 0]
    y1 = [0, 1, 0]

    # Plot the first triangle
    ax.fill(x1, y1, 'white')
    ax.plot(x1 + [0], y1 + [0], 'k')

    for i, color_index in enumerate(white_gray_triangles):
        color = 'white'
        if color_index == 1:
            gray_shade = random.uniform(0.2, 0.8)
            color = (gray_shade, gray_shade, gray_shade)  # Gray cell

        # Determine the coordinates of the new triangle
        if i % 2 == 0:
            x2 = [1 * (i // 2), 1 * (i // 2) + 1, 1 * (i // 2)]
            y2 = [0, 1, 1]
        else:
            x2 = [1 * ((i - 1) // 2) + 1, 1 * ((i + 1) // 2), 1 * ((i - 1) // 2)]
            y2 = [0, 1, 0]

        # Plot the new triangle
        ax.fill(x2, y2, color)
        ax.plot(x2 + [x2[0]], y2 + [y2[0]], 'k')

    plt.savefig(filename, bbox_inches='tight', pad_inches=0.5)
    plt.close()

    return sum(white_gray_triangles) / num_triangles, f"{sum(white_gray_triangles)}/{num_triangles}"

# %%
def generate_dataset(n_samples):
    """
    Generate a dataset of n_samples shapes and labels.
    Returns a tuple (X, y) where X is a list of shape data and y is a list of corresponding labels.
    """
    X, y = [], []
    for i in tqdm(range(n_samples)):
        shape_type, parts, black_parts = generate_shape()
        label = label_shape(parts, black_parts)
        # X.append((shape_type, parts, black_parts))
        # y.append(label)

        filename = os.path.join(OUTPUT_DIR, f"shape_{i}.png")

        # Calculate the fraction of black parts
        num_black_parts = sum(black_parts)
        if shape_type == "rectangle":
          fraction_black_parts, label = generate_rectangle(filename)
        elif shape_type == "circle":
          fraction_black_parts, label = generate_pie(filename)
        elif shape_type == "triangle":
          fraction_black_parts, label = generate_triangles(filename)

        # Write the label information to a CSV file
        with open("shapes_labels3.csv", "a", newline="") as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow([label, filename, shape_type, parts, black_parts, fraction_black_parts])
    # return X, y

# %%
generate_dataset(n_samples=10000)
# Out:
# 100%|██████████| 10000/10000 [18:00<00:00,  9.25it/s]

# %%
# !zip -r /content/shapes3.zip /content/shapes3
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/shapes3/shape_1894.png (deflated 15%)
#   adding: content/shapes3/shape_6100.png (deflated 71%)
#   adding: content/shapes3/shape_9564.png (deflated 54%)
#   adding: content/shapes3/shape_4056.png (deflated 17%)
#   adding: content/shapes3/shape_6451.png (deflated 83%)
#   adding: content/shapes3/shape_1088.png (deflated 66%)
#   adding: content/shapes3/shape_6558.png (deflated 15%)
#   adding: content/shapes3/shape_629.png (deflated 13%)
#   adding: content/shapes3/shape_2257.png (deflated 67%)
#   adding: content/shapes3/shape_1764.png (deflated 17%)
#   adding: content/shapes3/shape_720.png (deflated 77%)
#   adding: content/shapes3/shape_5550.png (deflated 19%)
#   adding: content/shapes3/shape_7471.png (deflated 15%)
#   adding: content/shapes3/shape_6246.png (deflated 12%)
#   adding: content/shapes3/shape_692.png (deflated 17%)
#   adding: content/shapes3/shape_9094.png (deflated 12%)
#   adding: content/shapes3/shape_6056.png (deflated 18%)
#   adding: content/shapes3/shape_1841.png (deflated 11%)
#   adding: content/shapes3/shape_398.png (deflated 11%)
#   adding: content/shapes3/shape_1560.png (deflated 16%)
#   adding: content/shapes3/shape_8385.png (deflated 13%)
#   adding: content/shapes3/shape_2416.png (deflated 17%)
#   adding: content/shapes3/shape_702.png (deflated 11%)
#   adding: content/shapes3/shape_3340.png (deflated 15%)
#   adding: content/shapes3/shape_634.png (deflated 77%)
#   adding: content/shapes3/shape_3707.png (deflated 10%)
#   adding: content/shapes3/shape_2480.png (deflated 66%)
#   adding: content/shapes3/shape_6207.png (deflated 77%)
#   adding: content/shapes3/shape_4805.png (deflated 77%)
#   adding: content/shapes3/shape_4650.png (deflated 78%)
#   adding: content/shapes3/shape_259.png (deflated 17%)
#   adding: content/shapes3/shape_8629.png (deflated 12%)
#   adding: content/shapes3/shape_1827.png (deflated 12%)
#   adding: content/shapes3/shape_7987.png (deflated 86%)
#   adding: content/shapes3/shape_6223.png (deflated 77%)
#   adding: content/shapes3/shape_5536.png (deflated 61%)
#   adding: content/shapes3/shape_2238.png (deflated 77%)
#   adding: content/shapes3/shape_1144.png (deflated 66%)
#   adding: content/shapes3/shape_3923.png (deflated 63%)
#   adding: content/shapes3/shape_4139.png (deflated 15%)
#   adding: content/shapes3/shape_5199.png (deflated 57%)
#   adding: content/shapes3/shape_1265.png (deflated 71%)
#   adding: content/shapes3/shape_7805.png (deflated 55%)
#   adding: content/shapes3/shape_2190.png (deflated 17%)
#   adding: content/shapes3/shape_5403.png (deflated 16%)
#   adding: content/shapes3/shape_368.png (deflated 71%)
#   adding: content/shapes3/shape_8095.png (deflated 17%)
#   adding: content/shapes3/shape_3754.png (deflated 10%)
#   adding: content/shapes3/shape_4217.png (deflated 13%)
#   adding: content/shapes3/shape_1606.png (deflated 18%)
#   adding: content/shapes3/shape_9641.png (deflated 62%)
#   adding: content/shapes3/shape_3694.png (deflated 13%)
#   adding: content/shapes3/shape_2056.png (deflated 70%)
#   adding: content/shapes3/shape_501.png (deflated 12%)
#   adding: content/shapes3/shape_3605.png (deflated 16%)
#   adding: content/shapes3/shape_2199.png (deflated 71%)
#   adding: content/shapes3/shape_2965.png (deflated 84%)
#   adding: content/shapes3/shape_3814.png (deflated 17%)
#   adding: content/shapes3/shape_1504.png (deflated 16%)
#   adding: content/shapes3/shape_3642.png (deflated 18%)
#   adding: content/shapes3/shape_1427.png (deflated 68%)
#   adding: content/shapes3/shape_131.png (deflated 14%)
#   adding: content/shapes3/shape_1215.png (deflated 12%)
#   adding: content/shapes3/shape_7657.png (deflated 54%)
#   adding: content/shapes3/shape_2039.png (deflated 15%)
#   adding: content/shapes3/shape_2101.png (deflated 69%)
#   adding: content/shapes3/shape_9652.png (deflated 11%)
#   adding: content/shapes3/shape_6317.png (deflated 15%)
#   adding: content/shapes3/shape_5349.png (deflated 12%)
#   adding: content/shapes3/shape_3976.png (deflated 53%)
#   adding: content/shapes3/shape_640.png (deflated 62%)
#   adding: content/shapes3/shape_8525.png (deflated 13%)
#   adding: content/shapes3/shape_4007.png (deflated 15%)
#   adding: content/shapes3/shape_2179.png (deflated 54%)
#   adding: content/shapes3/shape_3248.png (deflated 17%)
#   adding: content/shapes3/shape_4961.png (deflated 86%)
#   adding: content/shapes3/shape_6663.png (deflated 60%)
#   adding: content/shapes3/shape_9706.png (deflated 12%)
#   adding: content/shapes3/shape_5240.png (deflated 14%)
#   adding: content/shapes3/shape_1135.png (deflated 15%)
#   adding: content/shapes3/shape_6794.png (deflated 67%)
#   adding: content/shapes3/shape_2249.png (deflated 18%)
#   adding: content/shapes3/shape_4581.png (deflated 62%)
#   adding: content/shapes3/shape_5754.png (deflated 14%)
#   adding: content/shapes3/shape_6371.png (deflated 72%)
#   adding: content/shapes3/shape_2502.png (deflated 67%)
#   adding: content/shapes3/shape_358.png (deflated 16%)
#   adding: content/shapes3/shape_1169.png (deflated 15%)
#   adding: content/shapes3/shape_462.png (deflated 62%)
#   adding: content/shapes3/shape_9669.png (deflated 12%)
#   adding: content/shapes3/shape_2494.png (deflated 78%)
#   adding: content/shapes3/shape_2973.png (deflated 11%)
#   adding: content/shapes3/shape_8892.png (deflated 15%)
#   adding: content/shapes3/shape_4324.png (deflated 12%)
#   adding: content/shapes3/shape_8395.png (deflated 15%)
#   adding: content/shapes3/shape_9814.png (deflated 17%)
#   adding: content/shapes3/shape_472.png (deflated 12%)
#   adding: content/shapes3/shape_2220.png (deflated 11%)
#   adding: content/shapes3/shape_4456.png (deflated 16%)
#   adding: content/shapes3/shape_8046.png (deflated 12%)
#   adding: content/shapes3/shape_826.png (deflated 62%)
#   adding: content/shapes3/shape_6127.png (deflated 15%)
#   adding: content/shapes3/shape_43.png (deflated 15%)
#   adding: content/shapes3/shape_1864.png (deflated 16%)
#   adding: content/shapes3/shape_3489.png (deflated 59%)
#   adding: content/shapes3/shape_6202.png (deflated 78%)
#   adding: content/shapes3/shape_6675.png (deflated 67%)
#   adding: content/shapes3/shape_286.png (deflated 53%)
#   adding: content/shapes3/shape_2704.png (deflated 16%)
#   adding: content/shapes3/shape_2947.png (deflated 18%)
#   adding: content/shapes3/shape_8585.png (deflated 69%)
#   adding: content/shapes3/shape_9211.png (deflated 14%)
#   adding: content/shapes3/shape_400.png (deflated 84%)
#   adding: content/shapes3/shape_1831.png (deflated 13%)
#   adding: content/shapes3/shape_7530.png (deflated 12%)
#   adding: content/shapes3/shape_6446.png (deflated 69%)
#   adding: content/shapes3/shape_4732.png (deflated 77%)
#   adding: content/shapes3/shape_6020.png (deflated 19%)
#   adding: content/shapes3/shape_8228.png (deflated 16%)
#   adding: content/shapes3/shape_1188.png (deflated 16%)
#   adding: content/shapes3/shape_2851.png (deflated 18%)
#   adding: content/shapes3/shape_9049.png (deflated 12%)
#   adding: content/shapes3/shape_1626.png (deflated 18%)
#   adding: content/shapes3/shape_1357.png (deflated 12%)
#   adding: content/shapes3/shape_2680.png (deflated 15%)
#   adding: content/shapes3/shape_9335.png (deflated 13%)
#   adding: content/shapes3/shape_3287.png (deflated 58%)
#   adding: content/shapes3/shape_4106.png (deflated 10%)
#   adding: content/shapes3/shape_7826.png (deflated 15%)
#   adding: content/shapes3/shape_4358.png (deflated 67%)
#   adding: content/shapes3/shape_8798.png (deflated 53%)
#   adding: content/shapes3/shape_2605.png (deflated 54%)
#   adding: content/shapes3/shape_2850.png (deflated 17%)
#   adding: content/shapes3/shape_2521.png (deflated 62%)
#   adding: content/shapes3/shape_4202.png (deflated 13%)
#   adding: content/shapes3/shape_3651.png (deflated 56%)
#   adding: content/shapes3/shape_7893.png (deflated 15%)
#   adding: content/shapes3/shape_1957.png (deflated 14%)
#   adding: content/shapes3/shape_4119.png (deflated 11%)
#   adding: content/shapes3/shape_3244.png (deflated 17%)
#   adding: content/shapes3/shape_806.png (deflated 78%)
#   adding: content/shapes3/shape_4004.png (deflated 13%)
#   adding: content/shapes3/shape_9633.png (deflated 10%)
#   adding: content/shapes3/shape_3308.png (deflated 13%)
#   adding: content/shapes3/shape_9225.png (deflated 15%)
#   adding: content/shapes3/shape_1693.png (deflated 14%)
#   adding: content/shapes3/shape_1923.png (deflated 65%)
#   adding: content/shapes3/shape_9660.png (deflated 13%)
#   adding: content/shapes3/shape_2892.png (deflated 16%)
#   adding: content/shapes3/shape_2765.png (deflated 14%)
#   adding: content/shapes3/shape_3520.png (deflated 72%)
#   adding: content/shapes3/shape_4493.png (deflated 12%)
#   adding: content/shapes3/shape_4218.png (deflated 13%)
#   adding: content/shapes3/shape_4149.png (deflated 15%)
#   adding: content/shapes3/shape_2145.png (deflated 11%)
#   adding: content/shapes3/shape_5453.png (deflated 11%)
#   adding: content/shapes3/shape_1974.png (deflated 13%)
#   adding: content/shapes3/shape_3803.png (deflated 17%)
#   adding: content/shapes3/shape_3960.png (deflated 13%)
#   adding: content/shapes3/shape_7651.png (deflated 51%)
#   adding: content/shapes3/shape_6212.png (deflated 53%)
#   adding: content/shapes3/shape_9330.png (deflated 12%)
#   adding: content/shapes3/shape_6069.png (deflated 13%)
#   adding: content/shapes3/shape_133.png (deflated 14%)
#   adding: content/shapes3/shape_1525.png (deflated 15%)
#   adding: content/shapes3/shape_6454.png (deflated 19%)
#   adding: content/shapes3/shape_2841.png (deflated 16%)
#   adding: content/shapes3/shape_7897.png (deflated 14%)
#   adding: content/shapes3/shape_7853.png (deflated 12%)
#   adding: content/shapes3/shape_6734.png (deflated 11%)
#   adding: content/shapes3/shape_4052.png (deflated 11%)
#   adding: content/shapes3/shape_9931.png (deflated 19%)
#   adding: content/shapes3/shape_8566.png (deflated 66%)
#   adding: content/shapes3/shape_9119.png (deflated 78%)
#   adding: content/shapes3/shape_7311.png (deflated 12%)
#   adding: content/shapes3/shape_6873.png (deflated 19%)
#   adding: content/shapes3/shape_4573.png (deflated 12%)
#   adding: content/shapes3/shape_9465.png (deflated 15%)
#   adding: content/shapes3/shape_1231.png (deflated 84%)
#   adding: content/shapes3/shape_551.png (deflated 18%)
#   adding: content/shapes3/shape_3170.png (deflated 16%)
#   adding: content/shapes3/shape_6801.png (deflated 69%)
#   adding: content/shapes3/shape_1965.png (deflated 14%)
#   adding: content/shapes3/shape_7018.png (deflated 15%)
#   adding: content/shapes3/shape_4775.png (deflated 11%)
#   adding: content/shapes3/shape_8101.png (deflated 83%)
#   adding: content/shapes3/shape_9515.png (deflated 63%)
#   adding: content/shapes3/shape_4537.png (deflated 86%)
#   adding: content/shapes3/shape_2641.png (deflated 78%)
#   adding: content/shapes3/shape_2121.png (deflated 12%)
#   adding: content/shapes3/shape_7864.png (deflated 76%)
#   adding: content/shapes3/shape_49.png (deflated 15%)
#   adding: content/shapes3/shape_1921.png (deflated 11%)
#   adding: content/shapes3/shape_4651.png (deflated 10%)
#   adding: content/shapes3/shape_1328.png (deflated 11%)
#   adding: content/shapes3/shape_7441.png (deflated 15%)
#   adding: content/shapes3/shape_646.png (deflated 71%)
#   adding: content/shapes3/shape_1092.png (deflated 14%)
#   adding: content/shapes3/shape_5957.png (deflated 13%)
#   adding: content/shapes3/shape_3798.png (deflated 14%)
#   adding: content/shapes3/shape_427.png (deflated 84%)
#   adding: content/shapes3/shape_9976.png (deflated 16%)
#   adding: content/shapes3/shape_9772.png (deflated 16%)
#   adding: content/shapes3/shape_6084.png (deflated 17%)
#   adding: content/shapes3/shape_3748.png (deflated 17%)
#   adding: content/shapes3/shape_1515.png (deflated 18%)
#   adding: content/shapes3/shape_3676.png (deflated 71%)
#   adding: content/shapes3/shape_2097.png (deflated 11%)
#   adding: content/shapes3/shape_2110.png (deflated 16%)
#   adding: content/shapes3/shape_5850.png (deflated 71%)
#   adding: content/shapes3/shape_41.png (deflated 79%)
#   adding: content/shapes3/shape_4769.png (deflated 64%)
#   adding: content/shapes3/shape_8938.png (deflated 13%)
#   adding: content/shapes3/shape_5862.png (deflated 12%)
#   adding: content/shapes3/shape_8043.png (deflated 16%)
#   adding: content/shapes3/shape_4047.png (deflated 13%)
#   adding: content/shapes3/shape_3630.png (deflated 12%)
#   adding: content/shapes3/shape_6336.png (deflated 76%)
#   adding: content/shapes3/shape_5577.png (deflated 65%)
#   adding: content/shapes3/shape_5549.png (deflated 72%)
#   adding: content/shapes3/shape_7300.png (deflated 75%)
#   adding: content/shapes3/shape_7485.png (deflated 78%)
#   adding: content/shapes3/shape_252.png (deflated 18%)
#   adding: content/shapes3/shape_5840.png (deflated 11%)
#   adding: content/shapes3/shape_1387.png (deflated 13%)
#   adding: content/shapes3/shape_1255.png (deflated 14%)
#   adding: content/shapes3/shape_372.png (deflated 15%)
#   adding: content/shapes3/shape_426.png (deflated 18%)
#   adding: content/shapes3/shape_8090.png (deflated 17%)
#   adding: content/shapes3/shape_6034.png (deflated 17%)
#   adding: content/shapes3/shape_1611.png (deflated 67%)
#   adding: content/shapes3/shape_578.png (deflated 66%)
#   adding: content/shapes3/shape_1414.png (deflated 14%)
#   adding: content/shapes3/shape_8565.png (deflated 11%)
#   adding: content/shapes3/shape_4289.png (deflated 12%)
#   adding: content/shapes3/shape_1238.png (deflated 11%)
#   adding: content/shapes3/shape_2904.png (deflated 15%)
#   adding: content/shapes3/shape_6821.png (deflated 18%)
#   adding: content/shapes3/shape_9491.png (deflated 67%)
#   adding: content/shapes3/shape_5325.png (deflated 82%)
#   adding: content/shapes3/shape_2856.png (deflated 11%)
#   adding: content/shapes3/shape_9224.png (deflated 71%)
#   adding: content/shapes3/shape_1008.png (deflated 15%)
#   adding: content/shapes3/shape_3350.png (deflated 15%)
#   adding: content/shapes3/shape_6501.png (deflated 82%)
#   adding: content/shapes3/shape_8989.png (deflated 12%)
#   adding: content/shapes3/shape_8081.png (deflated 14%)
#   adding: content/shapes3/shape_1946.png (deflated 64%)
#   adding: content/shapes3/shape_9999.png (deflated 71%)
#   adding: content/shapes3/shape_3435.png (deflated 16%)
#   adding: content/shapes3/shape_9899.png (deflated 12%)
#   adding: content/shapes3/shape_6110.png (deflated 11%)
#   adding: content/shapes3/shape_8869.png (deflated 13%)
#   adding: content/shapes3/shape_664.png (deflated 77%)
#   adding: content/shapes3/shape_963.png (deflated 11%)
#   adding: content/shapes3/shape_6483.png (deflated 15%)
#   adding: content/shapes3/shape_7882.png (deflated 16%)
#   adding: content/shapes3/shape_9895.png (deflated 70%)
#   adding: content/shapes3/shape_3106.png (deflated 71%)
#   adding: content/shapes3/shape_7647.png (deflated 17%)
#   adding: content/shapes3/shape_3258.png (deflated 12%)
#   adding: content/shapes3/shape_6002.png (deflated 13%)
#   adding: content/shapes3/shape_9723.png (deflated 12%)
#   adding: content/shapes3/shape_8889.png (deflated 56%)
#   adding: content/shapes3/shape_7747.png (deflated 58%)
#   adding: content/shapes3/shape_9337.png (deflated 70%)
#   adding: content/shapes3/shape_2011.png (deflated 11%)
#   adding: content/shapes3/shape_6443.png (deflated 19%)
#   adding: content/shapes3/shape_7273.png (deflated 16%)
#   adding: content/shapes3/shape_4248.png (deflated 71%)
#   adding: content/shapes3/shape_5625.png (deflated 17%)
#   adding: content/shapes3/shape_9863.png (deflated 16%)
#   adding: content/shapes3/shape_7028.png (deflated 15%)
#   adding: content/shapes3/shape_6019.png (deflated 15%)
#   adding: content/shapes3/shape_3127.png (deflated 66%)
#   adding: content/shapes3/shape_3753.png (deflated 16%)
#   adding: content/shapes3/shape_2395.png (deflated 12%)
#   adding: content/shapes3/shape_9309.png (deflated 15%)
#   adding: content/shapes3/shape_2165.png (deflated 16%)
#   adding: content/shapes3/shape_4105.png (deflated 17%)
#   adding: content/shapes3/shape_6535.png (deflated 68%)
#   adding: content/shapes3/shape_9622.png (deflated 15%)
#   adding: content/shapes3/shape_7734.png (deflated 15%)
#   adding: content/shapes3/shape_1866.png (deflated 10%)
#   adding: content/shapes3/shape_9575.png (deflated 68%)
#   adding: content/shapes3/shape_5411.png (deflated 17%)
#   adding: content/shapes3/shape_1447.png (deflated 13%)
#   adding: content/shapes3/shape_3479.png (deflated 17%)
#   adding: content/shapes3/shape_3624.png (deflated 12%)
#   adding: content/shapes3/shape_4178.png (deflated 16%)
#   adding: content/shapes3/shape_4307.png (deflated 17%)
#   adding: content/shapes3/shape_6438.png (deflated 82%)
#   adding: content/shapes3/shape_605.png (deflated 14%)
#   adding: content/shapes3/shape_6240.png (deflated 11%)
#   adding: content/shapes3/shape_4949.png (deflated 83%)
#   adding: content/shapes3/shape_6216.png (deflated 15%)
#   adding: content/shapes3/shape_109.png (deflated 12%)
#   adding: content/shapes3/shape_853.png (deflated 77%)
#   adding: content/shapes3/shape_1686.png (deflated 12%)
#   adding: content/shapes3/shape_3213.png (deflated 15%)
#   adding: content/shapes3/shape_1869.png (deflated 15%)
#   adding: content/shapes3/shape_7918.png (deflated 67%)
#   adding: content/shapes3/shape_5817.png (deflated 70%)
#   adding: content/shapes3/shape_7768.png (deflated 65%)
#   adding: content/shapes3/shape_5026.png (deflated 15%)
#   adding: content/shapes3/shape_9323.png (deflated 79%)
#   adding: content/shapes3/shape_4377.png (deflated 72%)
#   adding: content/shapes3/shape_8033.png (deflated 55%)
#   adding: content/shapes3/shape_5358.png (deflated 64%)
#   adding: content/shapes3/shape_189.png (deflated 18%)
#   adding: content/shapes3/shape_6657.png (deflated 17%)
# ...
#   adding: content/shapes3/shape_6308.png (deflated 13%)
#   adding: content/shapes3/shape_4496.png (deflated 17%)
#   adding: content/shapes3/shape_8626.png (deflated 15%)
#   adding: content/shapes3/shape_8976.png (deflated 12%)
#   adding: content/shapes3/shape_7939.png (deflated 86%)
#   adding: content/shapes3/shape_9000.png (deflated 52%)
#   adding: content/shapes3/shape_1199.png (deflated 18%)
#   adding: content/shapes3/shape_5508.png (deflated 70%)
#   adding: content/shapes3/shape_8851.png (deflated 18%)
#   adding: content/shapes3/shape_9613.png (deflated 15%)
#   adding: content/shapes3/shape_9939.png (deflated 15%)
#   adding: content/shapes3/shape_8148.png (deflated 13%)
#   adding: content/shapes3/shape_8180.png (deflated 12%)
#   adding: content/shapes3/shape_5611.png (deflated 73%)
#   adding: content/shapes3/shape_5721.png (deflated 18%)
#   adding: content/shapes3/shape_8167.png (deflated 71%)
#   adding: content/shapes3/shape_9684.png (deflated 75%)
#   adding: content/shapes3/shape_8500.png (deflated 64%)
#   adding: content/shapes3/shape_5636.png (deflated 15%)
#   adding: content/shapes3/shape_9284.png (deflated 86%)
#   adding: content/shapes3/shape_7512.png (deflated 11%)
#   adding: content/shapes3/shape_523.png (deflated 15%)
#   adding: content/shapes3/shape_7114.png (deflated 77%)
#   adding: content/shapes3/shape_5859.png (deflated 14%)
#   adding: content/shapes3/shape_2612.png (deflated 18%)
#   adding: content/shapes3/shape_2634.png (deflated 16%)
#   adding: content/shapes3/shape_9228.png (deflated 70%)
#   adding: content/shapes3/shape_4786.png (deflated 54%)
#   adding: content/shapes3/shape_6363.png (deflated 72%)
#   adding: content/shapes3/shape_6851.png (deflated 74%)
#   adding: content/shapes3/shape_7868.png (deflated 83%)
#   adding: content/shapes3/shape_2259.png (deflated 65%)
#   adding: content/shapes3/shape_2498.png (deflated 75%)
#   adding: content/shapes3/shape_5092.png (deflated 11%)
#   adding: content/shapes3/shape_1734.png (deflated 11%)
#   adding: content/shapes3/shape_2478.png (deflated 67%)
#   adding: content/shapes3/shape_3028.png (deflated 17%)
#   adding: content/shapes3/shape_7004.png (deflated 12%)
#   adding: content/shapes3/shape_4486.png (deflated 65%)
#   adding: content/shapes3/shape_6647.png (deflated 66%)
#   adding: content/shapes3/shape_4333.png (deflated 60%)
#   adding: content/shapes3/shape_1438.png (deflated 73%)
#   adding: content/shapes3/shape_2517.png (deflated 50%)
#   adding: content/shapes3/shape_4239.png (deflated 11%)
#   adding: content/shapes3/shape_4837.png (deflated 17%)
#   adding: content/shapes3/shape_4045.png (deflated 11%)
#   adding: content/shapes3/shape_4283.png (deflated 17%)
#   adding: content/shapes3/shape_2928.png (deflated 71%)
#   adding: content/shapes3/shape_9374.png (deflated 12%)
#   adding: content/shapes3/shape_683.png (deflated 13%)
#   adding: content/shapes3/shape_574.png (deflated 20%)
#   adding: content/shapes3/shape_7465.png (deflated 77%)
#   adding: content/shapes3/shape_8685.png (deflated 12%)
#   adding: content/shapes3/shape_564.png (deflated 11%)
#   adding: content/shapes3/shape_7873.png (deflated 13%)
#   adding: content/shapes3/shape_6354.png (deflated 65%)
#   adding: content/shapes3/shape_1649.png (deflated 62%)
#   adding: content/shapes3/shape_9912.png (deflated 17%)
#   adding: content/shapes3/shape_266.png (deflated 15%)
#   adding: content/shapes3/shape_225.png (deflated 77%)
#   adding: content/shapes3/shape_8530.png (deflated 19%)
#   adding: content/shapes3/shape_192.png (deflated 17%)
#   adding: content/shapes3/shape_1950.png (deflated 14%)
#   adding: content/shapes3/shape_6875.png (deflated 11%)
#   adding: content/shapes3/shape_912.png (deflated 60%)
#   adding: content/shapes3/shape_3700.png (deflated 78%)
#   adding: content/shapes3/shape_5736.png (deflated 11%)
#   adding: content/shapes3/shape_1953.png (deflated 14%)
#   adding: content/shapes3/shape_2644.png (deflated 19%)
#   adding: content/shapes3/shape_4685.png (deflated 86%)
#   adding: content/shapes3/shape_4074.png (deflated 71%)
#   adding: content/shapes3/shape_1386.png (deflated 10%)
#   adding: content/shapes3/shape_1444.png (deflated 11%)
#   adding: content/shapes3/shape_9171.png (deflated 84%)
#   adding: content/shapes3/shape_7386.png (deflated 77%)
#   adding: content/shapes3/shape_9630.png (deflated 18%)
#   adding: content/shapes3/shape_2961.png (deflated 14%)
#   adding: content/shapes3/shape_6168.png (deflated 71%)
#   adding: content/shapes3/shape_8901.png (deflated 17%)
#   adding: content/shapes3/shape_6713.png (deflated 15%)
#   adding: content/shapes3/shape_7934.png (deflated 12%)
#   adding: content/shapes3/shape_6417.png (deflated 11%)
#   adding: content/shapes3/shape_3470.png (deflated 78%)
#   adding: content/shapes3/shape_1224.png (deflated 17%)
#   adding: content/shapes3/shape_6463.png (deflated 18%)
#   adding: content/shapes3/shape_1167.png (deflated 17%)
#   adding: content/shapes3/shape_3777.png (deflated 14%)
#   adding: content/shapes3/shape_4305.png (deflated 10%)
#   adding: content/shapes3/shape_5025.png (deflated 75%)
#   adding: content/shapes3/shape_8914.png (deflated 73%)
#   adding: content/shapes3/shape_4860.png (deflated 12%)
#   adding: content/shapes3/shape_9282.png (deflated 12%)
#   adding: content/shapes3/shape_8813.png (deflated 15%)
#   adding: content/shapes3/shape_188.png (deflated 18%)
#   adding: content/shapes3/shape_6630.png (deflated 15%)
#   adding: content/shapes3/shape_5370.png (deflated 78%)
#   adding: content/shapes3/shape_796.png (deflated 17%)
#   adding: content/shapes3/shape_85.png (deflated 17%)
#   adding: content/shapes3/shape_5879.png (deflated 78%)
#   adding: content/shapes3/shape_5424.png (deflated 11%)
#   adding: content/shapes3/shape_7339.png (deflated 15%)
#   adding: content/shapes3/shape_8205.png (deflated 12%)
#   adding: content/shapes3/shape_9682.png (deflated 17%)
#   adding: content/shapes3/shape_4880.png (deflated 15%)
#   adding: content/shapes3/shape_2627.png (deflated 19%)
#   adding: content/shapes3/shape_3720.png (deflated 67%)
#   adding: content/shapes3/shape_1609.png (deflated 65%)
#   adding: content/shapes3/shape_2045.png (deflated 17%)
#   adding: content/shapes3/shape_9315.png (deflated 70%)
#   adding: content/shapes3/shape_6786.png (deflated 57%)
#   adding: content/shapes3/shape_8138.png (deflated 12%)
#   adding: content/shapes3/shape_7443.png (deflated 17%)
#   adding: content/shapes3/shape_1888.png (deflated 66%)
#   adding: content/shapes3/shape_7315.png (deflated 11%)
#   adding: content/shapes3/shape_3843.png (deflated 68%)
#   adding: content/shapes3/shape_5165.png (deflated 15%)
#   adding: content/shapes3/shape_5147.png (deflated 17%)
#   adding: content/shapes3/shape_1181.png (deflated 53%)
#   adding: content/shapes3/shape_7551.png (deflated 75%)
#   adding: content/shapes3/shape_9765.png (deflated 64%)
#   adding: content/shapes3/shape_5592.png (deflated 12%)
#   adding: content/shapes3/shape_6426.png (deflated 11%)
#   adding: content/shapes3/shape_5333.png (deflated 13%)
#   adding: content/shapes3/shape_441.png (deflated 19%)
#   adding: content/shapes3/shape_6880.png (deflated 69%)
#   adding: content/shapes3/shape_8726.png (deflated 16%)
#   adding: content/shapes3/shape_1522.png (deflated 11%)
#   adding: content/shapes3/shape_7929.png (deflated 11%)
#   adding: content/shapes3/shape_6266.png (deflated 18%)
#   adding: content/shapes3/shape_5290.png (deflated 14%)
#   adding: content/shapes3/shape_7331.png (deflated 71%)
#   adding: content/shapes3/shape_4066.png (deflated 53%)
#   adding: content/shapes3/shape_8808.png (deflated 12%)
#   adding: content/shapes3/shape_7886.png (deflated 19%)
#   adding: content/shapes3/shape_3876.png (deflated 16%)
#   adding: content/shapes3/shape_1617.png (deflated 77%)
#   adding: content/shapes3/shape_2002.png (deflated 18%)
#   adding: content/shapes3/shape_5547.png (deflated 12%)
#   adding: content/shapes3/shape_9208.png (deflated 79%)
#   adding: content/shapes3/shape_5955.png (deflated 14%)
#   adding: content/shapes3/shape_212.png (deflated 54%)
#   adding: content/shapes3/shape_4209.png (deflated 16%)
#   adding: content/shapes3/shape_2509.png (deflated 15%)
#   adding: content/shapes3/shape_3626.png (deflated 18%)
#   adding: content/shapes3/shape_3504.png (deflated 68%)
#   adding: content/shapes3/shape_9742.png (deflated 13%)
#   adding: content/shapes3/shape_5385.png (deflated 11%)
#   adding: content/shapes3/shape_1811.png (deflated 82%)
#   adding: content/shapes3/shape_8441.png (deflated 72%)
#   adding: content/shapes3/shape_2758.png (deflated 12%)
#   adding: content/shapes3/shape_2447.png (deflated 77%)
#   adding: content/shapes3/shape_7048.png (deflated 18%)
#   adding: content/shapes3/shape_2137.png (deflated 72%)
#   adding: content/shapes3/shape_1168.png (deflated 18%)
#   adding: content/shapes3/shape_262.png (deflated 11%)
#   adding: content/shapes3/shape_6722.png (deflated 19%)
#   adding: content/shapes3/shape_4712.png (deflated 62%)
#   adding: content/shapes3/shape_4434.png (deflated 16%)
#   adding: content/shapes3/shape_8340.png (deflated 11%)
#   adding: content/shapes3/shape_1229.png (deflated 14%)
#   adding: content/shapes3/shape_3986.png (deflated 12%)
#   adding: content/shapes3/shape_540.png (deflated 82%)
#   adding: content/shapes3/shape_7632.png (deflated 12%)
#   adding: content/shapes3/shape_557.png (deflated 67%)
#   adding: content/shapes3/shape_6596.png (deflated 51%)
#   adding: content/shapes3/shape_2500.png (deflated 66%)
#   adding: content/shapes3/shape_5221.png (deflated 71%)
#   adding: content/shapes3/shape_2846.png (deflated 12%)
#   adding: content/shapes3/shape_1977.png (deflated 70%)
#   adding: content/shapes3/shape_3982.png (deflated 12%)
#   adding: content/shapes3/shape_4861.png (deflated 12%)
#   adding: content/shapes3/shape_9404.png (deflated 63%)
#   adding: content/shapes3/shape_6845.png (deflated 68%)
#   adding: content/shapes3/shape_2272.png (deflated 78%)
#   adding: content/shapes3/shape_1176.png (deflated 16%)
#   adding: content/shapes3/shape_8600.png (deflated 10%)
#   adding: content/shapes3/shape_2188.png (deflated 78%)
#   adding: content/shapes3/shape_6881.png (deflated 18%)
#   adding: content/shapes3/shape_7649.png (deflated 15%)
#   adding: content/shapes3/shape_4899.png (deflated 16%)
#   adding: content/shapes3/shape_1625.png (deflated 73%)
#   adding: content/shapes3/shape_8862.png (deflated 14%)
#   adding: content/shapes3/shape_6344.png (deflated 12%)
#   adding: content/shapes3/shape_4789.png (deflated 61%)
#   adding: content/shapes3/shape_8073.png (deflated 61%)
#   adding: content/shapes3/shape_1257.png (deflated 18%)
#   adding: content/shapes3/shape_4696.png (deflated 18%)
#   adding: content/shapes3/shape_4627.png (deflated 15%)
#   adding: content/shapes3/shape_1281.png (deflated 12%)
#   adding: content/shapes3/shape_981.png (deflated 11%)
#   adding: content/shapes3/shape_4782.png (deflated 11%)
#   adding: content/shapes3/shape_6166.png (deflated 19%)
#   adding: content/shapes3/shape_7624.png (deflated 14%)
#   adding: content/shapes3/shape_5619.png (deflated 17%)
#   adding: content/shapes3/shape_3727.png (deflated 77%)
#   adding: content/shapes3/shape_442.png (deflated 12%)
#   adding: content/shapes3/shape_6364.png (deflated 17%)
#   adding: content/shapes3/shape_134.png (deflated 17%)
#   adding: content/shapes3/shape_9120.png (deflated 13%)
#   adding: content/shapes3/shape_8822.png (deflated 73%)
#   adding: content/shapes3/shape_5495.png (deflated 54%)
#   adding: content/shapes3/shape_9420.png (deflated 13%)
#   adding: content/shapes3/shape_1377.png (deflated 17%)
#   adding: content/shapes3/shape_1855.png (deflated 11%)
#   adding: content/shapes3/shape_6357.png (deflated 12%)
#   adding: content/shapes3/shape_9864.png (deflated 11%)
#   adding: content/shapes3/shape_4168.png (deflated 12%)
#   adding: content/shapes3/shape_9318.png (deflated 78%)
#   adding: content/shapes3/shape_8160.png (deflated 18%)
#   adding: content/shapes3/shape_1836.png (deflated 18%)
#   adding: content/shapes3/shape_2479.png (deflated 54%)
#   adding: content/shapes3/shape_8397.png (deflated 15%)
#   adding: content/shapes3/shape_7738.png (deflated 15%)
#   adding: content/shapes3/shape_51.png (deflated 11%)
#   adding: content/shapes3/shape_5584.png (deflated 16%)
#   adding: content/shapes3/shape_150.png (deflated 15%)
#   adding: content/shapes3/shape_6225.png (deflated 69%)
#   adding: content/shapes3/shape_663.png (deflated 11%)
#   adding: content/shapes3/shape_3951.png (deflated 19%)
#   adding: content/shapes3/shape_7275.png (deflated 75%)
#   adding: content/shapes3/shape_5203.png (deflated 83%)
#   adding: content/shapes3/shape_9136.png (deflated 13%)
#   adding: content/shapes3/shape_4770.png (deflated 62%)
#   adding: content/shapes3/shape_171.png (deflated 15%)
#   adding: content/shapes3/shape_4504.png (deflated 17%)
#   adding: content/shapes3/shape_7960.png (deflated 67%)
#   adding: content/shapes3/shape_5129.png (deflated 75%)
#   adding: content/shapes3/shape_7830.png (deflated 18%)
#   adding: content/shapes3/shape_8743.png (deflated 12%)
#   adding: content/shapes3/shape_296.png (deflated 10%)
#   adding: content/shapes3/shape_2526.png (deflated 12%)
#   adding: content/shapes3/shape_6190.png (deflated 78%)
#   adding: content/shapes3/shape_9071.png (deflated 13%)
#   adding: content/shapes3/shape_1436.png (deflated 14%)
#   adding: content/shapes3/shape_1114.png (deflated 15%)
#   adding: content/shapes3/shape_573.png (deflated 16%)
#   adding: content/shapes3/shape_5826.png (deflated 61%)
#   adding: content/shapes3/shape_7322.png (deflated 15%)
#   adding: content/shapes3/shape_3760.png (deflated 15%)
#   adding: content/shapes3/shape_2930.png (deflated 12%)
#   adding: content/shapes3/shape_7049.png (deflated 65%)
#   adding: content/shapes3/shape_3105.png (deflated 15%)
#   adding: content/shapes3/shape_6718.png (deflated 13%)
#   adding: content/shapes3/shape_908.png (deflated 65%)
#   adding: content/shapes3/shape_3344.png (deflated 86%)
#   adding: content/shapes3/shape_1736.png (deflated 15%)
#   adding: content/shapes3/shape_2983.png (deflated 83%)
#   adding: content/shapes3/shape_6423.png (deflated 17%)
#   adding: content/shapes3/shape_1324.png (deflated 14%)
#   adding: content/shapes3/shape_65.png (deflated 77%)
#   adding: content/shapes3/shape_3612.png (deflated 11%)
#   adding: content/shapes3/shape_9471.png (deflated 11%)
#   adding: content/shapes3/shape_6043.png (deflated 15%)
#   adding: content/shapes3/shape_9550.png (deflated 77%)
#   adding: content/shapes3/shape_5522.png (deflated 12%)
#   adding: content/shapes3/shape_4086.png (deflated 82%)
#   adding: content/shapes3/shape_6070.png (deflated 71%)
#   adding: content/shapes3/shape_3290.png (deflated 17%)
#   adding: content/shapes3/shape_4020.png (deflated 12%)
#   adding: content/shapes3/shape_7195.png (deflated 11%)
#   adding: content/shapes3/shape_374.png (deflated 11%)
#   adding: content/shapes3/shape_8579.png (deflated 18%)
#   adding: content/shapes3/shape_3237.png (deflated 15%)
#   adding: content/shapes3/shape_5795.png (deflated 15%)
#   adding: content/shapes3/shape_7008.png (deflated 17%)
#   adding: content/shapes3/shape_9144.png (deflated 84%)
#   adding: content/shapes3/shape_6048.png (deflated 16%)
#   adding: content/shapes3/shape_9289.png (deflated 77%)
#   adding: content/shapes3/shape_6937.png (deflated 65%)
#   adding: content/shapes3/shape_6414.png (deflated 17%)
#   adding: content/shapes3/shape_4150.png (deflated 11%)
#   adding: content/shapes3/shape_6416.png (deflated 66%)
#   adding: content/shapes3/shape_7707.png (deflated 13%)
#   adding: content/shapes3/shape_7296.png (deflated 86%)
#   adding: content/shapes3/shape_3118.png (deflated 83%)
#   adding: content/shapes3/shape_5934.png (deflated 17%)
#   adding: content/shapes3/shape_9646.png (deflated 14%)
#   adding: content/shapes3/shape_3425.png (deflated 16%)
#   adding: content/shapes3/shape_4013.png (deflated 57%)
#   adding: content/shapes3/shape_3867.png (deflated 58%)
#   adding: content/shapes3/shape_9866.png (deflated 65%)
#   adding: content/shapes3/shape_6439.png (deflated 13%)
#   adding: content/shapes3/shape_5525.png (deflated 11%)
#   adding: content/shapes3/shape_3623.png (deflated 14%)
#   adding: content/shapes3/shape_7766.png (deflated 78%)
#   adding: content/shapes3/shape_4461.png (deflated 13%)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r "/content/shapes3.zip" "/content/drive/MyDrive/"
# !cp -r "/content/shapes_labels3.csv" "/content/drive/MyDrive/"
